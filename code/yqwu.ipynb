# %%
import pandas as pd
import os

work_dir = "/home/clasper/2509/sysusky_ai4s/data"
os.chdir(work_dir)

df = pd.read_csv("candidate.csv")
df.head()
# Out:
#   molecule_id                                             SMILES   MolWt  \
# 0   CAND_0001                  CC(=O)c1ccc2nc(-c3ccccc3)n(O)c2c1  252.27
# 1   CAND_0002        Cc1cccc(C2CC(N[C@@H](C)C(=O)NCc3ccco3)C2)c1  312.41
# 2   CAND_0003          O=S(=O)(c1ccc(NC(=S)N2CCOCC2)cc1)N1CCCCC1  369.51
# 3   CAND_0004  C=C1CC[C@@H](O)[C@]2(C)CC[C@@](O)(C(C)(C)O)C[C...  254.37
# 4   CAND_0005  Cc1ccc(S(=O)(=O)NC(=O)Nc2ccccc2C(=O)/C=C/c2ccn...  421.48
#
#    LogP  HBA  HBD     pIC50
# 0  3.14    4    1  6.745071
# 1  3.13    3    2  5.792604
# 2  1.89    4    1  6.971533
# 3  2.01    3    3  8.284545
# 4  3.80    5    2  5.648770

# %%
df.drop("pIC50", axis = 1, inplace = True)
df.head()
# Out:
#   molecule_id                                             SMILES   MolWt  \
# 0   CAND_0001                  CC(=O)c1ccc2nc(-c3ccccc3)n(O)c2c1  252.27
# 1   CAND_0002        Cc1cccc(C2CC(N[C@@H](C)C(=O)NCc3ccco3)C2)c1  312.41
# 2   CAND_0003          O=S(=O)(c1ccc(NC(=S)N2CCOCC2)cc1)N1CCCCC1  369.51
# 3   CAND_0004  C=C1CC[C@@H](O)[C@]2(C)CC[C@@](O)(C(C)(C)O)C[C...  254.37
# 4   CAND_0005  Cc1ccc(S(=O)(=O)NC(=O)Nc2ccccc2C(=O)/C=C/c2ccn...  421.48
#
#    LogP  HBA  HBD
# 0  3.14    4    1
# 1  3.13    3    2
# 2  1.89    4    1
# 3  2.01    3    3
# 4  3.80    5    2

# %%
df.to_csv("data_1.csv", index = False)
